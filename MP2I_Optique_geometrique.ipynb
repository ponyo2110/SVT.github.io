# %% [markdown]
# <a href="https://colab.research.google.com/github/ponyo2110/SVT.github.io/blob/main/MP2I_Optique_geometrique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#EXERCICE 6

import numpy as np
import matplotlib.pyplot as plt

############
# PARAMÈTRES
############
R = 1        # rayon du dioptre sphérique (en mètres)
n = 1.51     # indice de la lentille
hmax = 0.3   # distance maximale du rayon incident (en mètres)
N = 10

##########################
# PRÉPARATION DE LA FIGURE
##########################
fig = plt.figure(figsize=(12,8))
plt.plot([-2*R, 5*R], np.zeros(2), "--k") # axe optique
fig.axes[0].set_aspect("equal") # même échelle sur les deux axes
plt.xlim(-2*R, 5*R)
plt.xlabel("x (m)")
plt.ylabel("y (m)")
# Dioptre sphérique
theta = np.linspace(-np.pi/2, np.pi/2, 101)
xd = R * np.cos(theta) - R
yd = R * np.sin(theta)
plt.plot(xd, yd, "k")
plt.plot([xd[0], xd[-1]], [yd[0], yd[-1]], "k")

#################
# TRACÉ DE RAYONS
#################
for h in np.linspace(-hmax, hmax, N):
    # Coordonnées des différents points
    xA, yA = (-2 * R, h)                 # coordonnées du point A
    xI, yI = (-R, h)                     # coordonnées du point I
    xJ, yJ = (np.sqrt(R**2 - h**2)-R, h) # coordonnées du point J
    # Angles au niveau du dioptre sphérique
    i = np.arcsin(h / R)     # angle d'incidence
    r = np.arcsin(n * h / R) # angle de réfraction
    xK, yK = (xJ + h / np.tan(r-i), 0)   # coordonnées du point K
    xB, yB = (2*xK-xJ, -h)               # coordonnées du point B
    # Tracé de la marche des rayons
    x = [xA, xI, xJ, xK, xB]
    y = [yA, yI, yJ, yK, yB]
    plt.plot(x, y, "red")
plt.show()

# %%
#Exercice 8

import numpy as np
import matplotlib.pyplot as plt

############
# PARAMÈTRES
############
R = 1        # rayon du dioptre sphérique (en mètres)
n = 1.51     # indice de la lentille
hmax = 0.3   # distance maximale du rayon incident (en mètres)
N = 3

##########################
# PRÉPARATION DE LA FIGURE
##########################
fig = plt.figure(figsize=(12,8))
plt.plot([-2*R, 5*R], np.zeros(2), "--k") # axe optique
fig.axes[0].set_aspect("equal") # même échelle sur les deux axes
plt.xlim(-2*R, 5*R)
plt.xlabel("x (m)")
plt.ylabel("y (m)")
# Dioptre sphérique
theta = np.linspace(-np.pi/2, np.pi/2, 101)
xd = R * np.cos(theta) - R
yd = R * np.sin(theta)
plt.plot(xd, yd, "k")
plt.plot([xd[0], xd[-1]], [yd[0], yd[-1]], "k")

#################
# TRACÉ DE RAYONS
#################
for h in np.linspace(-hmax, hmax, N):
    # Coordonnées des différents points
    xA, yA = (-2 * R, h)                 # coordonnées du point A
    xI, yI = (-R, h)                     # coordonnées du point I
    xJ, yJ = (np.sqrt(R**2 - h**2)-R, h) # coordonnées du point J
    # Angles au niveau du dioptre sphérique
    i = np.arcsin(h / R)     # angle d'incidence
    r = np.arcsin(n * h / R) # angle de réfraction
    xK, yK = (xJ + h / np.tan(r-i), 0)   # coordonnées du point K
    xB, yB = (2*xK-xJ, -h)               # coordonnées du point B
    # Tracé de la marche des rayons
    x = [xA, xI, xJ, xK, xB]
    y = [yA, yI, yJ, yK, yB]
    plt.plot(x, y, "red")
plt.show()
# Out:
# /tmp/ipython-input-205799844.py:39: RuntimeWarning: invalid value encountered in scalar divide
#   xK, yK = (xJ + h / np.tan(r-i), 0)   # coordonnées du point K

# %%
#Exercice 8


import numpy as np
import matplotlib.pyplot as plt

############
# PARAMÈTRES
############
R = 1        # rayon du dioptre sphérique (en mètres)
n = 1.51     # indice de la lentille
hmax = 0.3   # distance maximale du rayon incident (en mètres)
N = 100

##########################
# PRÉPARATION DE LA FIGURE
##########################
fig = plt.figure(figsize=(12,8))
plt.plot([-2*R, 5*R], np.zeros(2), "--k") # axe optique
fig.axes[0].set_aspect("equal") # même échelle sur les deux axes
plt.xlim(-2*R, 5*R)
plt.xlabel("x (m)")
plt.ylabel("y (m)")
# Dioptre sphérique
theta = np.linspace(-np.pi/2, np.pi/2, 101)
xd = R * np.cos(theta) - R
yd = R * np.sin(theta)
plt.plot(xd, yd, "k")
plt.plot([xd[0], xd[-1]], [yd[0], yd[-1]], "k")

#################
# TRACÉ DE RAYONS
#################
for h in np.linspace(-hmax, hmax, N):
    # Coordonnées des différents points
    xA, yA = (-2 * R, h)                 # coordonnées du point A
    xI, yI = (-R, h)                     # coordonnées du point I
    xJ, yJ = (np.sqrt(R**2 - h**2)-R, h) # coordonnées du point J
    # Angles au niveau du dioptre sphérique
    i = np.arcsin(h / R)     # angle d'incidence
    r = np.arcsin(n * h / R) # angle de réfraction
    xK, yK = (xJ + h / np.tan(r-i), 0)   # coordonnées du point K
    xB, yB = (2*xK-xJ, -h)               # coordonnées du point B
    # Tracé de la marche des rayons
    x = [xA, xI, xJ, xK, xB]
    y = [yA, yI, yJ, yK, yB]
    plt.plot(x, y, "red")
plt.show()

# %%
#Exercice11

import numpy as np
import matplotlib.pyplot as plt

############
# PARAMÈTRES
############
R = 1        # rayon du dioptre sphérique (en mètres)
n = 1.51     # indice de la lentille

eta=0.1
RD=eta*R
hmax = RD   # distance maximale du rayon incident (en mètres)
N = 10


##########################
# PRÉPARATION DE LA FIGURE
##########################
fig = plt.figure(figsize=(12,8))
plt.plot([-2*R, 5*R], np.zeros(2), "--k") # axe optique
fig.axes[0].set_aspect("equal") # même échelle sur les deux axes
plt.xlim(-2*R, 5*R)
plt.xlabel("x (m)")
plt.ylabel("y (m)")
# Dioptre sphérique
theta = np.linspace(-np.pi/2, np.pi/2, 101)
xd = R * np.cos(theta) - R
yd = R * np.sin(theta)
plt.plot(xd, yd, "k")
plt.plot([xd[0], xd[-1]], [yd[0], yd[-1]], "k")

#################
# TRACÉ DE RAYONS
#################
for h in np.linspace(-hmax, hmax, N):
    # Coordonnées des différents points
    xA, yA = (-2 * R, h)                 # coordonnées du point A
    xI, yI = (-R, h)                     # coordonnées du point I
    xJ, yJ = (np.sqrt(R**2 - h**2)-R, h) # coordonnées du point J
    # Angles au niveau du dioptre sphérique
    i = np.arcsin(h / R)     # angle d'incidence
    r = np.arcsin(n * h / R) # angle de réfraction
    xK, yK = (xJ + h / np.tan(r-i), 0)   # coordonnées du point K
    xB, yB = (2*xK-xJ, -h)               # coordonnées du point B
    # Tracé de la marche des rayons
    x = [xA, xI, xJ, xK, xB]
    y = [yA, yI, yJ, yK, yB]
    plt.plot(x, y, "red")
plt.show()

# %%
#Exercice11

import numpy as np
import matplotlib.pyplot as plt

############
# PARAMÈTRES
############
R = 1        # rayon du dioptre sphérique (en mètres)
n = 1.51     # indice de la lentille

eta=0.2
RD=eta*R
hmax = RD   # distance maximale du rayon incident (en mètres)
N = 10

##########################
# PRÉPARATION DE LA FIGURE
##########################
fig = plt.figure(figsize=(12,8))
plt.plot([-2*R, 5*R], np.zeros(2), "--k") # axe optique
fig.axes[0].set_aspect("equal") # même échelle sur les deux axes
plt.xlim(-2*R, 5*R)
plt.xlabel("x (m)")
plt.ylabel("y (m)")
# Dioptre sphérique
theta = np.linspace(-np.pi/2, np.pi/2, 101)
xd = R * np.cos(theta) - R
yd = R * np.sin(theta)
plt.plot(xd, yd, "k")
plt.plot([xd[0], xd[-1]], [yd[0], yd[-1]], "k")

#################
# TRACÉ DE RAYONS
#################
for h in np.linspace(-hmax, hmax, N):
    # Coordonnées des différents points
    xA, yA = (-2 * R, h)                 # coordonnées du point A
    xI, yI = (-R, h)                     # coordonnées du point I
    xJ, yJ = (np.sqrt(R**2 - h**2)-R, h) # coordonnées du point J
    # Angles au niveau du dioptre sphérique
    i = np.arcsin(h / R)     # angle d'incidence
    r = np.arcsin(n * h / R) # angle de réfraction
    xK, yK = (xJ + h / np.tan(r-i), 0)   # coordonnées du point K
    xB, yB = (2*xK-xJ, -h)               # coordonnées du point B
    # Tracé de la marche des rayons
    x = [xA, xI, xJ, xK, xB]
    y = [yA, yI, yJ, yK, yB]
    plt.plot(x, y, "red")
plt.show()

# %%
#Exercice11

import numpy as np
import matplotlib.pyplot as plt

############
# PARAMÈTRES
############
R = 1        # rayon du dioptre sphérique (en mètres)
n = 1.51     # indice de la lentille

eta=0.3
RD=eta*R
hmax = RD   # distance maximale du rayon incident (en mètres)
N = 10

##########################
# PRÉPARATION DE LA FIGURE
##########################
fig = plt.figure(figsize=(12,8))
plt.plot([-2*R, 5*R], np.zeros(2), "--k") # axe optique
fig.axes[0].set_aspect("equal") # même échelle sur les deux axes
plt.xlim(-2*R, 5*R)
plt.xlabel("x (m)")
plt.ylabel("y (m)")
# Dioptre sphérique
theta = np.linspace(-np.pi/2, np.pi/2, 101)
xd = R * np.cos(theta) - R
yd = R * np.sin(theta)
plt.plot(xd, yd, "k")
plt.plot([xd[0], xd[-1]], [yd[0], yd[-1]], "k")

#################
# TRACÉ DE RAYONS
#################
for h in np.linspace(-hmax, hmax, N):
    # Coordonnées des différents points
    xA, yA = (-2 * R, h)                 # coordonnées du point A
    xI, yI = (-R, h)                     # coordonnées du point I
    xJ, yJ = (np.sqrt(R**2 - h**2)-R, h) # coordonnées du point J
    # Angles au niveau du dioptre sphérique
    i = np.arcsin(h / R)     # angle d'incidence
    r = np.arcsin(n * h / R) # angle de réfraction
    xK, yK = (xJ + h / np.tan(r-i), 0)   # coordonnées du point K
    xB, yB = (2*xK-xJ, -h)               # coordonnées du point B
    # Tracé de la marche des rayons
    x = [xA, xI, xJ, xK, xB]
    y = [yA, yI, yJ, yK, yB]
    plt.plot(x, y, "red")
plt.show()

# %%
#EXERCICE 15
import numpy as np
import matplotlib.pyplot as plt

############
# PARAMÈTRES
############
R = 1        # rayon du dioptre sphérique (en mètres)
n = 1.51     # indice de la lentille
h = 0.01     # petit décalage (rayon paraxial)


i = np.arcsin(h / R)       # angle
r = np.arcsin(n * h / R)

CK=(n*R)/(n*np.cos(i)-np.sqrt(1-n**2*np.sin(i)**2))
CO=R
OK=CK-CO

print(CO)

##########################
# DESSIN POUR VERIFIER
##########################
fig = plt.figure(figsize=(10,6))
plt.plot([-2*R, 5*R], np.zeros(2), "--k") # axe optique
fig.axes[0].set_aspect("equal")
plt.xlim(-2*R, 5*R)
plt.xlabel("x (m)")
plt.ylabel("y (m)")

# Dioptre sphérique
theta = np.linspace(-np.pi/2, np.pi/2, 101)
xd = R * np.cos(theta) - R
yd = R * np.sin(theta)
plt.plot(xd, yd, "k")
plt.plot([xd[0], xd[-1]], [yd[0], yd[-1]], "k")

# Tracé du rayon paraxial
xA, yA = (-2*R, h)
xI, yI = (-R, h)
x = [xA, xI, xJ, xK]
y = [yA, yI, yJ, yK]
plt.plot(x, y, "red")
plt.scatter([xK], [yK], color="blue", label="Point K (foyer)")
plt.legend()
plt.show()
# Out:
# 1
